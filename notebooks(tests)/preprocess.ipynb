# %% [markdown]
# # Dataset exploration

# %% [markdown]
# **Printing out columns of the dataset**

# %%
# Import necessary dependencies
import pandas as pd
import seaborn as sns
# import plotly.express as px
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/tracks_features.csv")

df.columns
# Out:
# Index(['id', 'name', 'album', 'album_id', 'artists', 'artist_ids',
#        'track_number', 'disc_number', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms',
#        'time_signature', 'year', 'release_date'],
#       dtype='object')

# %%
df.head()
# Out:
#                        id                   name                      album  \
# 0  7lmeHLHBe4nmXzuXc0HDjk                Testify  The Battle Of Los Angeles
# 1  1wsRitfRRtWyEapl0q22o8        Guerrilla Radio  The Battle Of Los Angeles
# 2  1hR0fIFK2qRG3f3RF70pb7       Calm Like a Bomb  The Battle Of Los Angeles
# 3  2lbASgTSoDO7MTuLAXlTW0              Mic Check  The Battle Of Los Angeles
# 4  1MQTmpYOZ6fcMQc56Hdo7T  Sleep Now In the Fire  The Battle Of Los Angeles
#
#                  album_id                       artists  \
# 0  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 1  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 2  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 3  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 4  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
#
#                    artist_ids  track_number  disc_number  explicit  \
# 0  ['2d0hyoQ5ynDBnkvAbJKORj']             1            1     False
# ...

# %%
df.dtypes
# Out:
# id                   object
# name                 object
# album                object
# album_id             object
# artists              object
# artist_ids           object
# track_number          int64
# disc_number           int64
# explicit               bool
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# duration_ms           int64
# time_signature      float64
# year                  int64
# release_date         object
# dtype: object

# %%
df.describe()
# Out:
#        track_number   disc_number  danceability        energy           key  \
# count  1.204025e+06  1.204025e+06  1.204025e+06  1.204025e+06  1.204025e+06
# mean   7.656352e+00  1.055906e+00  4.930565e-01  5.095363e-01  5.194151e+00
# std    5.994977e+00  2.953752e-01  1.896694e-01  2.946839e-01  3.536731e+00
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    3.000000e+00  1.000000e+00  3.560000e-01  2.520000e-01  2.000000e+00
# 50%    7.000000e+00  1.000000e+00  5.010000e-01  5.240000e-01  5.000000e+00
# 75%    1.000000e+01  1.000000e+00  6.330000e-01  7.660000e-01  8.000000e+00
# max    5.000000e+01  1.300000e+01  1.000000e+00  1.000000e+00  1.100000e+01
#
#            loudness          mode   speechiness  acousticness  \
# count  1.204025e+06  1.204025e+06  1.204025e+06  1.204025e+06
# mean  -1.180870e+01  6.714595e-01  8.438219e-02  4.467511e-01
# std    6.982132e+00  4.696827e-01  1.159914e-01  3.852014e-01
# ...

# %% [markdown]
# After some exploration, columns represent:
#
#  - `id` - a unique identifier for the track.
#
#  - `name` - the title of the track.
#
#  - `album` - the title of the album containing the track.
#
#  - `album_id` - a unique identifier for the album.
#
#  - `artists` - a list of artist names associated with the track.
#
#  - `artist_ids` - a list of strings, each representing a unique identifier for an artist.
#
#  - `track_number` - the order of the track within the album.
#
#  - `disc_number` - indicates which disc the track is on(some albums are multi-disc).
#
#  - `explicit` - indicates whether the track contains explicit content.
#
#  - `danceability` - a measure of how suitable a track is for dancing.
#
#  - `energy` - a measure of the intensity and activity of the track.
#
#  - `key` - the key using standard pitch class notation (e.g., 0 = C, 1 = C♯/D♭, etc.).
#
#  - `loudness` -  value between -60.0 and 7.234 dB.
#
#  - `mode` - 1 for major and 0 for minor.
#
#  - `speechiness` - a measure of the presence of spoken words in the track(I guess bigger value belongs to rap and smaller to dubstep or whatever).
#
#  - `acousticness` - a confidence measure of whether the track is acoustic.
#
#  - `instrumentalness` - a measure of the likelihood that the track contains no vocal content.
#
#  - `liveness` - a measure of the presence of an audience in the recording.
#
#  - `valence` - a measure of how cheerful is music.
#
#  - `tempo` - estimated tempo of the track in beats per minute (BPM).
#
#  - `duration_ms` - duration of the track in milliseconds.
#
#  - `time_signature` - the number of beats per bar(typically between 3 and 7).
#
#  - `year` - the release year of the track.
#
#  - `release_date` - the release date of the track.

# %%
df.isnull().sum()
# Out:
# id                   0
# name                 3
# album               11
# album_id             0
# artists              0
# artist_ids           0
# track_number         0
# disc_number          0
# explicit             0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# duration_ms          0
# time_signature       0
# year                 0
# release_date         0
# dtype: int64

# %%
# Select numeric features
numeric_features = df[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 
                       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 
                       'duration_ms', 'time_signature', 'year']]

# Calculate the correlation matrix
correlation_matrix = numeric_features.corr()

plt.figure(figsize=(12, 10))

# Draw the heatmap
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='magma', 
            vmin=-1, vmax=1, linewidths=.5, cbar_kws={"shrink": .8})

plt.title('Pearson Correlation Matrix of Spotify Audio Features')

plt.show()

# %% [markdown]
# **Some observations**:
#
# High positive correlation:
#  - `loudness` and `energy` - loud tracks represent more emotions and brings more energy to listener.
#  - `valence` and `danceability` - listener want to dance more when the track is cheerful.
#  - `valence` and `danceability` also correlate with both `loudness` and `energy`.
#
# High negative correlation:
#  - `loudness` and `energy` anticorrelate with `acousticness` - background music should not be loud and energetic.

# %% [markdown]
# **Small preprocessing**
#
# There are 3 tracks without a title and 11 tracks without an album title.
#
# In our opinion, it is not critical for music recommendation system, but those records might be dropped to avoid future bugs or blank output.

# %%
df = df.dropna(subset=['name', 'album'])

# %% [markdown]
# ### Data visualisation

# %%
def get_decade(year):
    period_start = int(year/10) * 10
    decade = '{}s'.format(period_start)
    return decade

df['decade'] = df.loc[:, 'year'].apply(func=get_decade)

sns.countplot(df.loc[:, 'decade'])
# Out:
# <Axes: xlabel='count', ylabel='decade'>
